# %% [markdown]
# # Bepaling van soortelijke warmte van water

# %% [markdown]
# # Introductie
#
# Water heeft een enorme buffercapaciteit: je moet veel energie toevoegen om de temperatuur van water een graad te verwarmen. In dit practicum gaan we de soortelijke warmte van water bepalen door een bekende hoeveelheid water te verwarmen met een bekende hoeveelheid energie, en de temperatuurstijging te meten.

# %% [markdown]
# # Theorie
#
# De soortelijke warmte $c$ van een stog is gedefinieerd als de hoeveelheid warmte $Q$ die nodig is om de temperatuur $T$ van een kilogram van het materiaal met één graad Celsius (of één Kelvin) te verhogen:
#
# $$
#     c = \frac{Q}{m \Delta T}
# $$ (eq:heat_capacity)
#
# Waarbij $Q$ de hoeveelheid warmte in Joules is, $m$ de massa in kilogram is en $\Delta T$ de verandering in temperatuur is.

# %% [markdown]
# # Methode en materialen
#
# ## Ontwerp
# Een waterbad met bekende massa aan water wordt verwarmd met een elektrisch verwarmingselement dat een bekende hoeveelheid energie levert.
# De temperatuur van het water wordt gemeten met een temperatuursensor.
# Door de temperatuurstijging als functie van de tijd te meten kan de soortelijke warmte van water worden berekend.
#
#
# ## Materialen
# Hieronder staat de lijst van benodigde materialen bij deze proef:
# - Maatbeker
# - Weegschaal
# - Water
# - Elektrisch verwarmingselement ($10 \mathrm{\Omega}$, $10 \mathrm{W}$)
# - Voedingsbron
# - Thermometer of temperatuursensor
# - Stopwatch of timer
#
# ```{figure} figures/cwater_setup.jpg
# :width: 70%
#
# Een schematische weergave van de opstelling
# ```
#
# ## Procedure
# ```{exercise}
# 1. Zet de maatbeker op de weegschaal en bepaal het gewicht van de maatbeker.
# 2. Vul de maatbeker met 400ml water en zet deze vervolgens opnieuw op de weegschaal.
# 3. Bepaal het gewicht van het water.
# 4. Roer doormiddel van de roervlo het water voorzichtig, zodat de temperatuur overal hetzelfde is.    5. Plaats het verwarmingselement in het water, zonder dat het de wanden van het bekerglas raakt en zorg ervoor dat er genoeg ruumte voor de roervlo blijft.
# 6. Sluit hierna het verwarmingselement aan (het verwarmingselement mag niet 30W overschreiden).
# 7. Plaats de thermometer eveneens in het water. Meet de begintemperatuur van het water.
# 8. Noteer het ingestelde vermogen.
# 9. Start tegelijkertijd de stopwatch en voeding.
# 10. verwarm het water gedurende een voorbepaalde tijd en meet tussendoor de temperatuur in een voorbepaalde interval.
# 11. Noteer de eindtijd en eindtemperatuur.
#
#
# 2. Geef jouw beschrijving van de procedure aan een ander team, zij verzamelen voor jou de data op basis van de gegevens.
# 3. Voer het experiment van een ander team uit op basis van hun beschrijving.
# 4. Analyseer de data die het andere groepje voor jou heeft verzameld.
# ```
#
#
# ## Veiligheid
# We maken gebruik van een $10 \mathrm{\Omega}$, $10 \mathrm{W}$ weerstand.
# Deze wordt snel heet.
# De bronspanning mag dan ook alleen aan wanneer de weerstand in het water zit.
# Raak de weerstand niet aan tijdens het experiment.
# Omdat de weerstand in het water zit, kunnen we wel het elektrisch vermogen hoger zetten zonder dat de weerstand oververhit raakt.
# Het maximaal vermogen mag $40 \mathrm{W}$ zijn.
# Daarbij moet de roerder wel aanstaan om de warmte goed te verdelen.
#
# ## Data analyse
# Tijdens het verwarmen van het water werd de temperatuur in vaste tijdsintervallen gemeten. Deze meetgegevens zijn geplot in python weergegeven als temperatuurfunctie van de tijd om het verwarmingsverloop te analyseren. De toegevoerde warmte is berekend uit het elektrisch vermogen van het verwarmingselement en de verwarmingstijd. Met de gemeten temperatuurstijging en de bekende massa van het water is vervolgens de soortelijke warmte bepaald.

# %% [markdown]
# # Resultaten

# %%
import numpy as np
import matplotlib.pyplot as plt
m_maatbeker = 264.6 #Massa in g
m_roervlo = 271.4-m_maatbeker #Massa in g
m_water = (832.2 - 271.4)/1000 #Massa in kg
t_water_begin = 20.5 #temperatuur in graden Celsius
P = 12*1.24 #Vermogen (P=U*I) in W
Q= P*5*60 #Warmte in Joule
t_water_eind = 22.6 #temperatuur in graden Celsius
c= Q/(m_water*(t_water_eind-t_water_begin)) #Soortelijke warmte in J/(kg*K)
print(c,'J/(kg*K)')
# Out:
# 3790.5033625433016 J/(kg*K)

# %%
# Plotten van de temperatuur tegen de tijd
plt.figure()
temp = [20.5, 20.6,20.9,20.9,21.3,21.5,21.8,21.9,22.3,22.4,22.5,22.6]
tijd = [0,30,60,90,120,150,180,210,240,270,300,330]
plt.plot(tijd,temp,'.')
plt.xlabel('$Tijd$ [s]')
plt.ylabel('$Temperatuur$ [°C]')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Discussie en conclusie
#
# De temperatuur stijging van water neemt zoals verwacht lineair toe bij temperaturen rond 20 graden Celsius. Ook wordt vanuit de resultaten de soortelijke warmte 'ruw' (Fout maar in de orde van grootte) benaderd vergeleken met de daadwerkelijke waarde van 4186 J/(kg*K). Dit is mogelijk door te systematische fouten dat er tijdens het experiment plaatsvinden tijdens het meten van de waardes, kleine hoeveelheid metingen dat er uitgevoerd zijn en warmteverlies dat er aan de omgeving verloren raakt wat bijdragen aan de onzekerheid in het resultaat.
